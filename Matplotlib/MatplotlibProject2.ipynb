# %% [markdown]
# # Project on Numpy

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
img = Image.open("D:\mountains.jpg")
img_arr = np.array(img)
img_arr[0:200 , 0:300: ,0]=0
img_arr[0:200 , 300:612: , 1]=0
img_arr[200:400, 0:300: ,2]=0
img_arr[200:410, 300:612: , [1,2]]=0
plt.imshow(img_arr)

# %%
#python image library
#img is variable
#coverts img into nparray to get x and y axis in a small format
#x and y axis is array's indexing
# red -> 0 , blue-> 2, green -> 1

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
face = Image.open(r"C:\Users\prade\OneDrive\Documents\NumpyProjectFace.jpeg")
face_arr = np.array(face)
face_arr[0:750, 0:450: ,0]=0
face_arr[0:750, 450:950: , 1]=0
face_arr[750:1300, 0:450: , 2]=0
face_arr[750:1310, 450:950: ,[0,1]]=0
plt.imshow(face_arr)

# %%
face_arr[0:750, 0:450: ,0]=0
face_arr[0:750, 450:900: , 1]=0
face_arr[750:1300, 0:450: , 2]=0
face_arr[750:1300, 450:950: ,[0,1]]=0
plt.imshow(face_arr)
