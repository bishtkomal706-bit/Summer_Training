# %% [markdown]
# # Pandas

# %%
#Create a series with five fruits names as their prices where fruit name should be index

import pandas as pd
a = pd.Series([200,150,120,50,60], index=['DragonFruit' , 'Litchi' , 'Blackberry' , 'Banana' , 'Mango'])
a
# Out:
# DragonFruit    200
# Litchi         150
# Blackberry     120
# Banana          50
# Mango           60
# dtype: int64

# %%
#create a dataframe for 5 students name, marks of 5 subject and rank

b = pd.DataFrame([['Komal',90,89,95,99,85, 1],
               ['Karan',78,67,56,45,87, 3],
               ['Priya', 90,89,79,98,99,2]], index=[1,2,3], columns = ['Name','DAA','Maths','OOPS','DE','COA','Rank'])
b
# Out:
#     Name  DAA  Maths  OOPS  DE  COA  Rank
# 1  Komal   90     89    95  99   85     1
# 2  Karan   78     67    56  45   87     3
# 3  Priya   90     89    79  98   99     2

# %% [markdown]
# # Data Loading

# %%
import pandas as pd                    #importing the libraries
df = pd.read_csv("D:\mtcars2.csv")     #loading the data
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
#pd.read_excel
#pd.read_html
#pd.read_pdf
#pd.read_word
#pd.read_json

# %%
df.shape
# Out:
# (32, 13)

# %%
import pandas as pd                          #importing the libraries
df = pd.read_csv("D:\mtcars2.csv")
df.info
# Out:
# <bound method DataFrame.info of     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %% [markdown]
# # Data Info Gathering

# %%
df.head()
# Out:
#    S.No         Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
df.tail()
# Out:
#     S.No      Unnamed: 1   mpg  cyl   disp   hp  drat     wt  qsec  vs  am  \
# 27    28    Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.9   1   1
# 28    29  Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.5   0   1
# 29    30    Ferrari Dino  19.7    6  145.0  175  3.62  2.770  15.5   0   1
# 30    31   Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.6   0   1
# 31    32      Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.6   1   1
#
#     gear  carb
# 27     5     2
# 28     5     4
# 29     5     6
# 30     5     8
# 31     4     2

# %%
df.head(9)
# Out:
#    S.No         Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5     6            Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1   0
# 6     7         Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7     8          Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8     9           Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2
# 5     3     1
# 6     3     4
# 7     4     2
# 8     4     2

# %%
df.min()
# Out:
# S.No                    1
# Unnamed: 1    AMC Javelin
# mpg                  10.4
# cyl                     4
# disp                 71.1
# hp                     52
# drat                 2.76
# wt                  1.513
# qsec                 14.5
# vs                      0
# am                      0
# gear                    3
# carb                    1
# dtype: object

# %%
df.max()
# Out:
# S.No                  32
# Unnamed: 1    Volvo 142E
# mpg                 33.9
# cyl                    8
# disp               472.0
# hp                   335
# drat                4.93
# wt                 5.424
# qsec                22.9
# vs                     1
# am                     1
# gear                   5
# carb                   8
# dtype: object

# %%
df.describe()
# Out:
#             S.No        mpg        cyl        disp          hp       drat  \
# count  32.000000  32.000000  32.000000   32.000000   32.000000  32.000000
# mean   16.500000  20.090625   6.187500  230.721875  146.687500   3.596563
# std     9.380832   6.026948   1.785922  123.938694   68.562868   0.534679
# min     1.000000  10.400000   4.000000   71.100000   52.000000   2.760000
# 25%     8.750000  15.425000   4.000000  120.825000   96.500000   3.080000
# 50%    16.500000  19.200000   6.000000  196.300000  123.000000   3.695000
# 75%    24.250000  22.800000   8.000000  326.000000  180.000000   3.920000
# max    32.000000  33.900000   8.000000  472.000000  335.000000   4.930000
#
#               wt       qsec         vs         am       gear     carb
# count  32.000000  29.000000  32.000000  32.000000  32.000000  32.0000
# mean    3.217250  17.674828   0.437500   0.406250   3.687500   2.8125
# std     0.978457   1.780394   0.504016   0.498991   0.737804   1.6152
# ...

# %%
df.mpg.median()
# Out:
# 19.2

# %%
df.count()
# Out:
# S.No          32
# Unnamed: 1    32
# mpg           32
# cyl           32
# disp          32
# hp            32
# drat          32
# wt            32
# qsec          29
# vs            32
# am            32
# gear          32
# carb          32
# dtype: int64

# %%
#missing value in dataset:-->

#can be fill by mean, median, mode
#median becoz it will not affect the data too much . eg 1,2,3,4,5,... mean-3 median -3 .. if 1,2,3,4,5,100 then mean-19.5 median -3.5
#differnce is clear after adding 1 value there is a long differnce in mean and can affect the data

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# S.No          0
# Unnamed: 1    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          3
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
y=df.qsec.median()
y
# Out:
# 17.42

# %%
df.fillna({'qsec':y},inplace = True)
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460  17.42   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
df.isnull().sum()
# Out:
# S.No          0
# Unnamed: 1    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          0
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
