# %% [markdown]
# # Data Loading + CLeaning

# %%
import pandas as pd
df = pd.read_csv(r'D:\archive (1)\ai_jobs.csv')
df
# Out:
#              job_id                  job_title  company_type    industry  \
# 0      0IFD0TVBDIVU             MLOps Engineer  Research Lab   Education
# 1      ZMF8MDD4V30T               Data Analyst       Startup   Education
# 2      CX1945NQ4FMY             MLOps Engineer  Research Lab        Tech
# 3      QJ7YHL1C32OC          Applied Scientist  Research Lab  Healthcare
# 4      F0T0PVN9ER14  Machine Learning Engineer  Research Lab     Finance
# ...             ...                        ...           ...         ...
# 49995  UN0T2IZO2KCL              AI Researcher           MNC      Retail
# 49996  CETZGCR42LC8             Data Scientist       Startup      Retail
# 49997  EQ9PTEJEFKUI               Data Analyst       Startup  Healthcare
# 49998  92UNH47RTAGS             Data Scientist  Research Lab  Healthcare
# 49999  QIN2HZHOH6O6          Applied Scientist           MNC      Retail
#
#          country       city remote_type experience_level  \
# ...

# %%
df.isnull().sum()
# Out:
# job_id                  0
# job_title               0
# company_type            0
# industry                0
# country                 0
# city                    0
# remote_type             0
# experience_level        0
# min_experience_years    0
# salary_min_usd          0
# salary_max_usd          0
# employment_type         0
# posted_year             0
# company_size            0
# dtype: int64

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\prade\Downloads\archive (2)\Industry.csv")
df
# Out:
#                          Company Name CD_Industry  \
# 0                 Aksh Optifibre Ltd.       Cable
# 1                    Birla Cable Ltd.       Cable
# 2                            CMI Ltd.       Cable
# 3         Cords Cable Industries Ltd.       Cable
# 4                  Delton Cables Ltd.       Cable
# 5   Diamond Power Infrastructure Ltd.       Cable
# 6                   Eon Electric Ltd.       Cable
# 7                 Finolex Cables Ltd.       Cable
# 8                      GR Cables Ltd.       Cable
# 9                 KEI Industries Ltd.       Cable
# 10             Nicco Corporation Ltd.       Cable
# 11      Paramount Communications Ltd.       Cable
# 12         Precision Wires India Ltd.       Cable
# 13            Salzer Electronics Ltd.       Cable
# 14               Savant Infocomm Ltd.       Cable
# 15                  SGN Telecoms Ltd.       Cable
# 16     Shilpi Cable Technologies Ltd.       Cable
# 17         Sterlite Technologies Ltd.       Cable
# ...

# %%
df.isnull().sum()
# Out:
# Company Name                                      0
# CD_Industry                                       0
# BS_Total Reserves/Total Assets                    0
# BS_Total Reserves/BS_Total Current Liabilities    0
# BS_Total Reserves/Net Assets                      0
#                                                  ..
# Share return Month 10                             2
# Share return Month 11                             3
# sum                                               0
# Standard Deviation                                0
# Risk Adjected Return                              0
# Length: 546, dtype: int64

# %%
df.drop(columns=['Share return Month 7' ], inplace = True)

# %%
df
# Out:
#                          Company Name CD_Industry  \
# 0                 Aksh Optifibre Ltd.       Cable
# 1                    Birla Cable Ltd.       Cable
# 2                            CMI Ltd.       Cable
# 3         Cords Cable Industries Ltd.       Cable
# 4                  Delton Cables Ltd.       Cable
# 5   Diamond Power Infrastructure Ltd.       Cable
# 6                   Eon Electric Ltd.       Cable
# 7                 Finolex Cables Ltd.       Cable
# 8                      GR Cables Ltd.       Cable
# 9                 KEI Industries Ltd.       Cable
# 10             Nicco Corporation Ltd.       Cable
# 11      Paramount Communications Ltd.       Cable
# 12         Precision Wires India Ltd.       Cable
# 13            Salzer Electronics Ltd.       Cable
# 14               Savant Infocomm Ltd.       Cable
# 15                  SGN Telecoms Ltd.       Cable
# 16     Shilpi Cable Technologies Ltd.       Cable
# 17         Sterlite Technologies Ltd.       Cable
# ...

# %%
df.isnull().sum()
# Out:
# Company Name                                      0
# CD_Industry                                       0
# BS_Total Reserves/Total Assets                    0
# BS_Total Reserves/BS_Total Current Liabilities    0
# BS_Total Reserves/Net Assets                      0
#                                                  ..
# Share return Month 6                              4
# Share return Month 9                              0
# sum                                               0
# Standard Deviation                                0
# Risk Adjected Return                              0
# Length: 542, dtype: int64

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\prade\Downloads\archive (2)\housing.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
x = df.total_bedrooms.median()
x
# Out:
# 435.0

# %%
#df['total_bedrooms'].fillna(x,inplace=True)
df.fillna({'total_bedrooms':x},inplace=True)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df.drop(columns=['ocean_proximity'],inplace=True)
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.to_csv('Numerical_dataset')

# %%
pwd
# Out:
# 'C:\\Users\\prade'

# %%
df.to_csv('Numerical_dataset',index=False)

# %%
pwd
# Out:
# 'C:\\Users\\prade'

# %%
df.to_csv('Numerical_dataset.csv',index=False)

# %%
import pandas as pd
df = pd.read_csv(r"Numerical_dataset.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
x = [10,10,10,20,30,30,30,50,65,75,135,150]
ax1 = plt.subplot()
ax1.boxplot(x)
plt.show()

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\prade\Downloads\archive (1)\Amazon.csv")
df
# Out:
#           OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0      ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1      ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2      ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3      ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4      ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
# ...           ...         ...         ...            ...       ...
# 99995  ORD0099996  2023-03-07  CUST001356    Karan Joshi    P00047
# 99996  ORD0099997  2021-11-24  CUST031254  Sunita Kapoor    P00046
# 99997  ORD0099998  2023-04-29  CUST012579     Aman Gupta    P00030
# 99998  ORD0099999  2021-11-01  CUST026243   Simran Gupta    P00046
# 99999  ORD0100000  2021-12-04  CUST029492   Sunita Reddy    P00019
#
#                ProductName           Category       Brand  Quantity  \
# 0               Drone Mini              Books   BrightLux         3
# ...

# %%
df.isnull().sum()
# Out:
# OrderID          0
# OrderDate        0
# CustomerID       0
# CustomerName     0
# ProductID        0
# ProductName      0
# Category         0
# Brand            0
# Quantity         0
# UnitPrice        0
# Discount         0
# Tax              0
# ShippingCost     0
# TotalAmount      0
# PaymentMethod    0
# OrderStatus      0
# City             0
# State            0
# Country          0
# SellerID         0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 99995    False
# 99996    False
# 99997    False
# 99998    False
# 99999    False
# Length: 100000, dtype: bool

# %%
df.isnull()
# Out:
#        OrderID  OrderDate  CustomerID  CustomerName  ProductID  ProductName  \
# 0        False      False       False         False      False        False
# 1        False      False       False         False      False        False
# 2        False      False       False         False      False        False
# 3        False      False       False         False      False        False
# 4        False      False       False         False      False        False
# ...        ...        ...         ...           ...        ...          ...
# 99995    False      False       False         False      False        False
# 99996    False      False       False         False      False        False
# 99997    False      False       False         False      False        False
# 99998    False      False       False         False      False        False
# 99999    False      False       False         False      False        False
#
# ...

# %%
df.drop(columns=['OrderID','SellerID','CustomerID','ProductID'],inplace=True)
df
# Out:
#         OrderDate   CustomerName          ProductName           Category  \
# 0      2023-01-31  Vihaan Sharma           Drone Mini              Books
# 1      2023-12-30    Pooja Kumar           Microphone     Home & Kitchen
# 2      2022-05-10    Sneha Singh  Power Bank 20000mAh           Clothing
# 3      2023-07-18   Vihaan Reddy       Webcam Full HD     Home & Kitchen
# 4      2023-02-04  Aditya Kapoor              T-Shirt           Clothing
# ...           ...            ...                  ...                ...
# 99995  2023-03-07    Karan Joshi    Memory Card 128GB        Electronics
# 99996  2021-11-24  Sunita Kapoor          Car Charger  Sports & Outdoors
# 99997  2023-04-29     Aman Gupta          Dress Shirt  Sports & Outdoors
# 99998  2021-11-01   Simran Gupta          Car Charger  Sports & Outdoors
# 99999  2021-12-04   Sunita Reddy        LED Desk Lamp     Home & Kitchen
#
#             Brand  Quantity  UnitPrice  Discount     Tax  ShippingCost  \
# ...

# %%
df.to_csv('Amazon_Sales_Dataset.csv',index=False)
df
# Out:
#         OrderDate   CustomerName          ProductName           Category  \
# 0      2023-01-31  Vihaan Sharma           Drone Mini              Books
# 1      2023-12-30    Pooja Kumar           Microphone     Home & Kitchen
# 2      2022-05-10    Sneha Singh  Power Bank 20000mAh           Clothing
# 3      2023-07-18   Vihaan Reddy       Webcam Full HD     Home & Kitchen
# 4      2023-02-04  Aditya Kapoor              T-Shirt           Clothing
# ...           ...            ...                  ...                ...
# 99995  2023-03-07    Karan Joshi    Memory Card 128GB        Electronics
# 99996  2021-11-24  Sunita Kapoor          Car Charger  Sports & Outdoors
# 99997  2023-04-29     Aman Gupta          Dress Shirt  Sports & Outdoors
# 99998  2021-11-01   Simran Gupta          Car Charger  Sports & Outdoors
# 99999  2021-12-04   Sunita Reddy        LED Desk Lamp     Home & Kitchen
#
#             Brand  Quantity  UnitPrice  Discount     Tax  ShippingCost  \
# ...

# %%
pwd
# Out:
# 'C:\\Users\\prade'
