# %%
import pandas as pd
df = pd.read_csv(r"D:\train.csv")
df
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0      0x4607     INDORES13DEL02                   37                     4.9
# 1      0xb379     BANGRES18DEL02                   34                     4.5
# 2      0x5d6d     BANGRES19DEL01                   23                     4.4
# 3      0x7a6a    COIMBRES13DEL02                   38                     4.7
# 4      0x70a2     CHENRES12DEL01                   32                     4.6
# ...        ...                ...                 ...                     ...
# 45588  0x7c09      JAPRES04DEL01                   30                     4.8
# 45589  0xd641      AGRRES16DEL01                   21                     4.6
# 45590  0x4f8d     CHENRES08DEL03                   30                     4.9
# 45591  0x5eee    COIMBRES11DEL01                   20                     4.7
# 45592  0x5fb2   RANCHIRES09DEL02                   23                     4.9
#
# ...

# %%
import pandas as pd
df = pd.read_csv(r"D:\mtcars2.csv")
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %% [markdown]
# # Data Cleaning

# %%
# Remove / Delete Unwanted Columns [Temporary Delete]

df.drop(columns=['S.No', 'gear', 'vs'])
# Out:
#              Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  am  carb
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   1     4
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   1     4
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1     1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   0     1
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0     2
# 5               Valiant  18.1    6  225.0  105  2.76  3.460    NaN   0     1
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0     4
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   0     2
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   0     2
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   0     4
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   0     4
# ...

# %%
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
df.drop(columns = ['S.No'], inplace = True)

# %%
df
# Out:
#              Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#Rename the column_name:

df.rename(columns = {'Unnamed: 1' : 'Name'})
# Out:
#                    Name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df
# Out:
#              Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#Permanently rename the column_name

df.rename(columns = {'Unnamed: 1' : 'Name'}, inplace = True)

# %%
df
# Out:
#                    Name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460    NaN   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#Duplicates

df.duplicated()    #gives false - if no duplicates, true - if duplicates
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
#Checking total no of dupliactes
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#if exist duplicates then apply command --> df.drop_duplicated()

# %%
#Null Values Or NAN

df.isnull()
# Out:
#      Name    mpg    cyl   disp     hp   drat     wt   qsec     vs     am  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False   True  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
# check no of null values
df.isnull().sum()
# Out:
# Name    0
# mpg     0
# cyl     0
# disp    0
# hp      0
# drat    0
# wt      0
# qsec    3
# vs      0
# am      0
# gear    0
# carb    0
# dtype: int64

# %%
#in above shows, there are 3 null values in column qsec
#4 ways to fill null values --> 1.pattern filling 
#a
#b
#c

#a
#b
#here i can fill by myself the missing values as d as it is a pattern

# %%
# 2. Mode
df['qsec'].value_counts()
# Out:
# qsec
# 17.02    2
# 16.46    1
# 14.60    1
# 15.50    1
# 14.50    1
# 16.90    1
# 16.70    1
# 17.05    1
# 15.41    1
# 17.30    1
# 16.87    1
# 20.01    1
# 19.90    1
# 18.52    1
# 17.42    1
# 17.82    1
# 17.98    1
# 18.00    1
# 17.60    1
# 17.40    1
# 18.90    1
# 18.30    1
# 22.90    1
# 20.00    1
# 15.84    1
# 19.44    1
# 18.61    1
# 18.60    1
# Name: count, dtype: int64

# %%
#Mean
#Median
x = df.qsec.median()
x
# Out:
# 17.42

# %%
#To fill values in place of  nan/null which we found through median
#df['qsec'].fillna(x, inplace = True)
df.fillna({'qsec':x}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Name    0
# mpg     0
# cyl     0
# disp    0
# hp      0
# drat    0
# wt      0
# qsec    0
# vs      0
# am      0
# gear    0
# carb    0
# dtype: int64

# %%
#TO GET SPECIFIC DATA BY INDEX --> iloc and loc
#iloc --> Index by location [last index not included]
df.iloc[:,:]
# Out:
#                    Name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  17.42   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.iloc[0:5 , 0:3]
# Out:
#                 Name   mpg  cyl
# 0          Mazda RX4  21.0    6
# 1      Mazda RX4 Wag  21.0    6
# 2         Datsun 710  22.8    4
# 3     Hornet 4 Drive  21.4    6
# 4  Hornet Sportabout  18.7    8

# %%
df.iloc[0:5:2, 0:8:2]  #df.iloc[strow : endrow: rowstep , scol : endcol : colstep]
# Out:
#                 Name  cyl   hp    wt
# 0          Mazda RX4    6  110  2.62
# 2         Datsun 710    4   93  2.32
# 4  Hornet Sportabout    8  175  3.44

# %%
#loc --> index by labels [last index included]
df.loc[0:5 , 'Name' :'cyl']
# Out:
#                 Name   mpg  cyl
# 0          Mazda RX4  21.0    6
# 1      Mazda RX4 Wag  21.0    6
# 2         Datsun 710  22.8    4
# 3     Hornet 4 Drive  21.4    6
# 4  Hornet Sportabout  18.7    8
# 5            Valiant  18.1    6

# %%
df.loc[[0,4,8],['Name','wt']]
# Out:
#                 Name    wt
# 0          Mazda RX4  2.62
# 4  Hornet Sportabout  3.44
# 8           Merc 230  3.15

# %%
#SORT
df.sort_values(by='cyl')  #sort in ascending by cyl
# Out:
#                    Name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  17.42   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  17.42   1   1
# ...

# %%
df.sort_values(by='cyl' , ascending = False)   #in descending
# Out:
#                    Name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   0
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# ...

# %%
#sorting by 2 columns in ascending
df.sort_values(by=['cyl','wt'])   #fisrt col will be sorted firstly
# Out:
#                    Name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   1
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  17.42   1   1
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   1
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  17.42   1   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# ...

# %%
#Filter
df['hp']>100
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26    False
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# Name: hp, dtype: bool

# %%
df[df['hp']>100]
# Out:
#                    Name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  17.42   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   0
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   0
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# ...

# %%
#filtering 2 column together

(df['cyl']>6)  & (df['hp']>200)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14     True
# 15     True
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23     True
# 24    False
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# dtype: bool

# %%
df[(df['cyl']>6)  &  (df['hp']>200)]
# Out:
#                    Name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   0
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   0
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   1
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   1
#
#     gear  carb
# 6      3     4
# 14     3     4
# 15     3     4
# 16     3     4
# 23     3     4
# 28     5     4
# 30     5     8

# %%
df
# Out:
#                    Name   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  17.42   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#PRACTICE 

#WAP to check the characters are present in a string or not
a = input('Enter the name')
a
# Out:
# Enter the name Komal Bisht
# 'Komal Bisht'

# %%
'Komal' in a
# Out:
# True

# %%
' Bis' in a
# Out:
# True

# %%
a.find('m')
# Out:
# 2
